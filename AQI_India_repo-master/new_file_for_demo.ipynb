# %% [markdown]
# <a href="https://colab.research.google.com/github/CMP7005/AQI_India_repo/blob/master/new_file_for_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('This is a test ipynb file to be added to repo')
# Out:
# This is a test ipynb file to be added to repo

# %%
print('second line to demonstrate the changes done in th file')
# Out:
# second line to demonstrate the changes done in th file
